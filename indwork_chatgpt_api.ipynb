# %%
# !pip install openai

# %%
import pandas as pd
import json
import geopandas as gpd
import os
from dotenv import load_dotenv
import requests
import openai
import re

pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
#________________________________________________________________________________________________________________
#This notebook includes parsing the text and categories from chat GPT API
#________________________________________________________________________________________________________________

# %%
# Read in the layer
places_wgs84 = gpd.read_file('data/places_wgs84.geojson')

# %%
# # Creating columns to store ai outputs
# places_wgs84["ai_short_description"] = None
# places_wgs84["ai_headlines"] = None

# %%
places_wgs84.head(2)
# Out:
#   GAZETTEER_ENTRY.NAME1  GAZETTEER_ENTRY.MOST_DETAIL_VIEW_RES  \
# 0               Beckton                                 20000
# 1              Plaistow                                 18000
#
#    GAZETTEER_ENTRY.LEAST_DETAIL_VIEW_RES  \
# 0                                  25000
# 1                                  25000
#
#                 GAZETTEER_ENTRY.SAME_AS_DBPEDIA                  geometry
# 0           http://dbpedia.org/resource/Beckton  POINT (0.05882 51.51583)
# 1  http://dbpedia.org/resource/Plaistow,_Newham  POINT (0.02419 51.52561)

# %%
# #________________________________________________________________________________________________________________
# # This API requires paid tokens, so I append the text I generated on the website white testing the requests' text
# #________________________________________________________________________________________________________________
# # Update ai_headlines for Stratford
# places_wgs84.loc[places_wgs84["GAZETTEER_ENTRY.NAME1"] == "Stratford", "ai_headlines"] = (
#     "Railway Junction Legacy, Industrial Revolution Hub, Olympic Regeneration Catalyst"
# )
# # Update ai_headlines for North Woolwich
# places_wgs84.loc[places_wgs84["GAZETTEER_ENTRY.NAME1"] == "Stratford", "ai_headlines"] = (
#     "Maritime Gateway, Dockyard Hub, Post-Industrial Revival"
# )
# # Update ai_short_description for Stratford
# places_wgs84.loc[places_wgs84["GAZETTEER_ENTRY.NAME1"] == "Stratford", "ai_short_description"] = (
#     "Stratford is a place of industrial history and bold regeneration, where its transformation from a railway hub and manufacturing center to an Olympic legacy site has sparked vibrant cultural and economic growth."
# )
# # Update ai_short_description for Harrow
# places_wgs84.loc[places_wgs84["GAZETTEER_ENTRY.NAME1"] == "Harrow", "ai_short_description"] = (
#     "Harrow is a place of academic distinction, where its prestigious schools and historic village charm "
#     "have evolved alongside suburban development, creating a unique blend of scholarly heritage and modern "
#     "family-friendly living."
# )
# # Update ai_short_description for North Woolwich
# places_wgs84.loc[places_wgs84["GAZETTEER_ENTRY.NAME1"] == "North Woolwich", "ai_short_description"] = (
#     "North Woolwich is a place of maritime industry and post-industrial reinvention, where its historic docklands and warehouses now give way to new residential and creative spaces, reflecting the area's ongoing transformation."
# )

# %%
#________________________________________________________________________________________________________________
# Creating json for batch request for headlines
#________________________________________________________________________________________________________________

with open("batch_requests.jsonl", "w") as f:
    for index, row in places_wgs84.iterrows():
        # Check if ai_headlines is None or NaN
        # if row["ai_headlines"] is None or pd.isna(row["ai_headlines"]):
        place_name = row["GAZETTEER_ENTRY.NAME1"]

        request_body = {
            "custom_id": place_name,  # Use place name as custom_id
            "method": "POST",
            "url": "/v1/chat/completions",
            "body": {
                "model": "gpt-4o-mini",  # Or your model choice
                "messages": [
                    {"role": "user", "content": f"Provide three distinct short phrases that capture the history and character of {place_name} in London. Focus on what makes this place specific—its history, roots, famous events and places in it, historic industries, parks, landmarks, or defining characteristics, and use simple, natural language. Avoid generic or overly grand phrases, don't mention community, make them feel like something a local might say. Keep each phrase under 5 words. Format them as comma-separated]"}
                ]
            }
        }

        # Write the request to the .jsonl file
        f.write(json.dumps(request_body) + "\n")

# %%
# #________________________________________________________________________________________________________________
# # Reading the batch for headlines
# #________________________________________________________________________________________________________________

# headlines_batch_file_path = "batch_67c7ae1e35f4819082ac91d0e62e8c74_output.jsonl"  # Change this to the actual file path

# # List to store each parsed JSON object
# responses = []

# # Open and read the .jsonl file
# with open(headlines_batch_file_path, "r") as f:
#     for line in f:
#         # Parse the JSON object from each line
#         response = json.loads(line.strip())  # Use .strip() to remove any unwanted whitespace

#         # Extract relevant details for the DataFrame
#         custom_id = response.get("custom_id")
        
#         # Safely extract the result by checking if 'choices' is non-empty
#         choices = response.get("body", {}).get("choices", [])
#         result = None  # Default to None if no result is found
#         if choices:  # Check if 'choices' is not empty
#             result = choices[0].get("message", {}).get("content", None)
        
#         # Append the extracted data as a dictionary
#         responses.append({
#             "custom_id": custom_id,
#             "result": result
#         })

# # Create a DataFrame from the list of responses
# df = pd.DataFrame(responses)

# # Display the DataFrame
# print(df)

# %%
headlines_batch_file_path = "batch_67ca3b8dca208190b1138c8aed47bcf6_output.jsonl"  # Change this to the actual file path
headlines_batch = []

with open(headlines_batch_file_path, "r") as f:
    for line in f:
        parsed_json = json.loads(line.strip())

        place_name = parsed_json.get("custom_id")
        choices = parsed_json.get("response", {}).get("body", {}).get("choices", [])
        response_content = choices[0]["message"]["content"] if choices else None

        phrases_list = []

        if response_content:
            # Fix JSON-like formatting (replace single quotes with double quotes)
            safe_json_str = response_content.replace("'", '"')

            try:
                # Try to parse as a JSON list
                phrases_list = json.loads(safe_json_str)
            except json.JSONDecodeError:
                # If JSON parsing fails, fallback to regex extraction
                phrases_list = re.findall(r"'(.*?)'", response_content)

        # Ensure clean extraction
        phrases_list = [phrase.strip() for phrase in phrases_list if isinstance(phrase, str)]

        # Append structured data
        headlines_batch.append({
            "place_name": place_name,
            "full_response": response_content,
            "line_1": phrases_list[0] if len(phrases_list) > 0 else None,
            "line_2": phrases_list[1] if len(phrases_list) > 1 else None,
            "line_3": phrases_list[2] if len(phrases_list) > 2 else None
        })

headlines_batch_df = pd.DataFrame(headlines_batch)
Why This Fix Works
✅ Fixes the Apostrophe Issue:

Converts "'Crystal Palace's proud home'" → "\"Crystal Palace's proud home\"" (valid JSON format).
Now it can be parsed correctly as a list.
✅ More Robust Parsing:

First, it tries to parse as JSON (which is more reliable).
If JSON fails, it falls back to regex extraction.
✅ No Accidental Splitting:

Prevents incorrect extraction like "Crystal Palace', ','s proud home".
Expected Output
✔ "['Crystal Palace's proud home','Historic railway connections','Diverse shops on Westow Hill']"
→ Extracts ["Crystal Palace's proud home", "Historic railway connections", "Diverse shops on Westow Hill"]

✔ "['Home of the historic Wharncliffe Viaduct', 'Once a hub for green farming', 'Greenford's hidden nature reserves thrive']"
→ Extracts ["Home of the historic Wharncliffe Viaduct", "Once a hub for green farming", "Greenford's hidden nature reserves thrive"]

This should now properly extract all phrases without breaking on apostrophes! 🚀 Let me know if it works for you.









        
headlines_batch_df = pd.DataFrame(headlines_batch)

# %%
headlines_batch
# Out:
# [{'place_name': 'Beckton',
#   'full_response': "['Home of the Beckton Gas Works','Beckton DLR station views','Historic dockland charm and character']",
#   'line_1': 'Home of the Beckton Gas Works',
#   'line_2': 'Beckton DLR station views',
#   'line_3': 'Historic dockland charm and character'},
#  {'place_name': 'Plaistow',
#   'full_response': "['Historic church on Plaistow Green','Home of the old gasworks','Where markets thrived for decades']",
#   'line_1': 'Historic church on Plaistow Green',
#   'line_2': 'Home of the old gasworks',
#   'line_3': 'Where markets thrived for decades'},
#  {'place_name': 'Leyton Marshes',
#   'full_response': "['Where football history runs deep', 'Quiet green space by the River', 'Once a bustling market hub']",
#   'line_1': 'Where football history runs deep',
#   'line_2': 'Quiet green space by the River',
#   'line_3': 'Once a bustling market hub'},
#  {'place_name': 'Stoke Newington',
#   'full_response': "['Home of the Abney Park Cemetery', 'Site of the old Stoke Newington Prison', 'Where the Hackney Revolution began']",
#   'line_1': 'Home of the Abney Park Cemetery',
#   'line_2': 'Site of the old Stoke Newington Prison',
#   'line_3': 'Where the Hackney Revolution began'},
#  {'place_name': 'Finsbury Park',
#   'full_response': "['Home of the Finsbury Park Market', 'The legendary Astoria Theatre scene', 'Green space amidst industrial roots']",
#   'line_1': 'Home of the Finsbury Park Market',
#   'line_2': 'The legendary Astoria Theatre scene',
#   'line_3': 'Green space amidst industrial roots'},
#  {'place_name': 'Highgate',
#   'full_response': "['Historic cemetery with famous residents', 'Charming village vibe near the city', 'Home of the iconic Highgate Ponds']",
#   'line_1': 'Historic cemetery with famous residents',
#   'line_2': 'Charming village vibe near the city',
#   'line_3': 'Home of the iconic Highgate Ponds'},
#  {'place_name': 'East Finchley',
#   'full_response': "['Home of the iconic Phoenix Cinema','Historic High Road charm','Green spaces and suburban vibe']",
#   'line_1': 'Home of the iconic Phoenix Cinema',
#   'line_2': 'Historic High Road charm',
#   'line_3': 'Green spaces and suburban vibe'},
#  {'place_name': 'Hampstead Garden Suburb',
#   'full_response': "['Arts and Crafts architecture everywhere','Historic homes nestled in greenery','Village vibe near the city']",
#   'line_1': 'Arts and Crafts architecture everywhere',
#   'line_2': 'Historic homes nestled in greenery',
#   'line_3': 'Village vibe near the city'},
#  {'place_name': 'Golders Green',
#   'full_response': "['Home of the Jewish community','Historic bus garage memories','The iconic Golders Green crematorium']",
#   'line_1': 'Home of the Jewish community',
#   'line_2': 'Historic bus garage memories',
#   'line_3': 'The iconic Golders Green crematorium'},
#  {'place_name': 'Hendon',
#   'full_response': "['Home of the RAF Museum','Historic suburban charm','High street with diverse eateries']",
#   'line_1': 'Home of the RAF Museum',
#   'line_2': 'Historic suburban charm',
#   'line_3': 'High street with diverse eateries'},
#  {'place_name': 'Kingsbury',
#   'full_response': "['Home of the historic Kingsbury Manor', 'The old market buzz on weekends', 'Close to the Neasden Temple']",
#   'line_1': 'Home of the historic Kingsbury Manor',
#   'line_2': 'The old market buzz on weekends',
#   'line_3': 'Close to the Neasden Temple'},
#  {'place_name': 'Wembley Park',
#   'full_response': "['Home of the iconic Wembley Stadium', 'Historic site of the 1948 Olympics', 'Vibrant spot for live music events']",
#   'line_1': 'Home of the iconic Wembley Stadium',
#   'line_2': 'Historic site of the 1948 Olympics',
#   'line_3': 'Vibrant spot for live music events'},
#  {'place_name': 'Kenton',
#   'full_response': "['Home of Kenton’s iconic cinema','The old railway station charm','Rich in multicultural eateries']",
#   'line_1': 'Home of Kenton’s iconic cinema',
#   'line_2': 'The old railway station charm',
#   'line_3': 'Rich in multicultural eateries'},
#  {'place_name': 'Harrow',
#   'full_response': "['Home to the famous Harrow School','Historic market town charm','Quaint streets with rich stories']",
#   'line_1': 'Home to the famous Harrow School',
#   'line_2': 'Historic market town charm',
#   'line_3': 'Quaint streets with rich stories'},
#  {'place_name': 'Sudbury',
#   'full_response': "['Historic market town vibe','Famous for its beautiful meadows','Home of the old ironworks']",
#   'line_1': 'Historic market town vibe',
#   'line_2': 'Famous for its beautiful meadows',
#   'line_3': 'Home of the old ironworks'},
#  {'place_name': 'Perivale',
#   'full_response': "['Historic industrial roots','Borders the Grand Union Canal','Home to iconic Hoover Building']",
#   'line_1': 'Historic industrial roots',
#   'line_2': 'Borders the Grand Union Canal',
#   'line_3': 'Home to iconic Hoover Building'},
#  {'place_name': 'Greenford',
#   'full_response': "['Home of the historic Wharncliffe Viaduct', 'Once a hub for green farming', 'Greenford's hidden nature reserves thrive']",
#   'line_1': 'Home of the historic Wharncliffe Viaduct',
#   'line_2': 'Once a hub for green farming',
#   'line_3': 'Greenford'},
#  {'place_name': 'Hanwell',
#   'full_response': "['Home of the historic Hanwell Asylum', 'The GrandUnion Canal winds through', 'Famous for its rich brewing past']",
#   'line_1': 'Home of the historic Hanwell Asylum',
#   'line_2': 'The GrandUnion Canal winds through',
#   'line_3': 'Famous for its rich brewing past'},
#  {'place_name': 'Isleworth',
#   'full_response': "['Home of the ancient Syon House', 'Where the river Thames winds gently', 'Once bustling with local breweries']",
#   'line_1': 'Home of the ancient Syon House',
#   'line_2': 'Where the river Thames winds gently',
#   'line_3': 'Once bustling with local breweries'},
#  {'place_name': 'Richmond upon Thames',
#   'full_response': "['Royal riverside town','Historic towpath walks','Local shops by the Thames']",
#   'line_1': 'Royal riverside town',
#   'line_2': 'Historic towpath walks',
#   'line_3': 'Local shops by the Thames'},
#  {'place_name': 'Upper Tooting',
#   'full_response': "['Home of the historic Tooting Market', 'Where the commons once grazed sheep', 'Bustling with curry houses and cafés']",
#   'line_1': 'Home of the historic Tooting Market',
#   'line_2': 'Where the commons once grazed sheep',
#   'line_3': 'Bustling with curry houses and cafés'},
#  {'place_name': 'Norbury',
#   'full_response': "['Home of the old Norbury Hall','Famous for its vibrant cricket scene','Local hub for diverse eateries']",
#   'line_1': 'Home of the old Norbury Hall',
#   'line_2': 'Famous for its vibrant cricket scene',
#   'line_3': 'Local hub for diverse eateries'},
#  {'place_name': 'Upper Norwood',
#   'full_response': "['Crystal Palace's proud home','Historic railway connections','Diverse shops on Westow Hill']",
#   'line_1': 'Crystal Palace',
#   'line_2': ',',
#   'line_3': ','},
#  {'place_name': 'Penge',
#   'full_response': "['Home of the Crystal Palace Park','Historic industrial heart of London','Quaint streets with quirky shops']",
#   'line_1': 'Home of the Crystal Palace Park',
#   'line_2': 'Historic industrial heart of London',
#   'line_3': 'Quaint streets with quirky shops'},
#  {'place_name': 'Beckenham',
#   'full_response': "['Historic clock tower chimes daily','Once a hub for tramways','Green spaces and charming parks']",
#   'line_1': 'Historic clock tower chimes daily',
#   'line_2': 'Once a hub for tramways',
#   'line_3': 'Green spaces and charming parks'},
#  {'place_name': 'Downham',
#   'full_response': "['Historic village with Victorian charm', 'Home of the iconic Downham Tap', 'Once thriving with local industries']",
#   'line_1': 'Historic village with Victorian charm',
#   'line_2': 'Home of the iconic Downham Tap',
#   'line_3': 'Once thriving with local industries'},
#  {'place_name': 'Eltham',
#   'full_response': "['Home of the historic Eltham Palace', 'Gateway to the Greenwich Borough', 'Charming village vibe with rich history']",
#   'line_1': 'Home of the historic Eltham Palace',
#   'line_2': 'Gateway to the Greenwich Borough',
#   'line_3': 'Charming village vibe with rich history'},
#  {'place_name': 'Shooters Hill',
#   'full_response': "['Where ancient roads meet today', 'Home of the historic shooter’s hill', 'Views of London from the heights']",
#   'line_1': 'Where ancient roads meet today',
#   'line_2': 'Home of the historic shooter’s hill',
#   'line_3': 'Views of London from the heights'},
#  {'place_name': 'Charlton',
#   'full_response': "['Home of the historic Charlton House', 'Famous for the Charlton Athletic FC', 'From shipbuilding to thriving suburbs']",
#   'line_1': 'Home of the historic Charlton House',
#   'line_2': 'Famous for the Charlton Athletic FC',
#   'line_3': 'From shipbuilding to thriving suburbs'},
#  {'place_name': 'Woolwich',
#   'full_response': "['Home of the Royal Arsenal','Historic naval river crossing','Diverse mix of old and new']",
#   'line_1': 'Home of the Royal Arsenal',
#   'line_2': 'Historic naval river crossing',
#   'line_3': 'Diverse mix of old and new'},
#  {'place_name': 'Silvertown',
#   'full_response': "['Docklands history and redevelopment','Site of the famous Tate & Lyle factory','Close to the Thames Barrier']",
#   'line_1': 'Docklands history and redevelopment',
#   'line_2': 'Site of the famous Tate & Lyle factory',
#   'line_3': 'Close to the Thames Barrier'},
#  {'place_name': 'Canning Town',
#   'full_response': "['Docklands history and regeneration','Home of the famous Canning Town Market','Mix of old industry and new homes']",
#   'line_1': 'Docklands history and regeneration',
#   'line_2': 'Home of the famous Canning Town Market',
#   'line_3': 'Mix of old industry and new homes'},
#  {'place_name': 'Bromley',
#   'full_response': "['Historic market town vibe','Home of the famous Bromley North station','Green spaces like Crystal Palace Park']",
#   'line_1': 'Historic market town vibe',
#   'line_2': 'Home of the famous Bromley North station',
#   'line_3': 'Green spaces like Crystal Palace Park'},
#  {'place_name': 'Hampstead Heath',
#   'full_response': "['Ancient woodlands and wild ponds', 'Site of summer prom concerts', 'The hill with epic city views']",
#   'line_1': 'Ancient woodlands and wild ponds',
#   'line_2': 'Site of summer prom concerts',
#   'line_3': 'The hill with epic city views'},
#  {'place_name': 'Neasden',
#   'full_response': "['First tube station in 1907','Buddhist temple bustling with visitors','Home of the famous Neasden roundabout']",
#   'line_1': 'First tube station in 1907',
#   'line_2': 'Buddhist temple bustling with visitors',
#   'line_3': 'Home of the famous Neasden roundabout'},
#  {'place_name': 'Wembley',
#   'full_response': "['Home of the iconic stadium','Historic sporting events hub','Vibrant multicultural atmosphere']",
#   'line_1': 'Home of the iconic stadium',
#   'line_2': 'Historic sporting events hub',
#   'line_3': 'Vibrant multicultural atmosphere'},
#  {'place_name': 'Brentford',
#   'full_response': "['Home of the mighty Bees','Historic docks and riverside pubs','Where Brentford Lock meets the Thames']",
#   'line_1': 'Home of the mighty Bees',
#   'line_2': 'Historic docks and riverside pubs',
#   'line_3': 'Where Brentford Lock meets the Thames'},
#  {'place_name': 'Streatham',
#   'full_response': "['Home of the legendary Ice Rink','Historic high street charm','Bustling markets and diverse culture']",
#   'line_1': 'Home of the legendary Ice Rink',
#   'line_2': 'Historic high street charm',
#   'line_3': 'Bustling markets and diverse culture'},
#  {'place_name': 'West Norwood',
#   'full_response': "['Historic cemetery with famous residents','Local markets and vintage shops','Victorian architecture along Norwood Road']",
#   'line_1': 'Historic cemetery with famous residents',
#   'line_2': 'Local markets and vintage shops',
#   'line_3': 'Victorian architecture along Norwood Road'},
#  {'place_name': 'Dulwich',
#   'full_response': "['Home to the Dulwich Picture Gallery','Historic village with green spaces','Sought-after area for families']",
#   'line_1': 'Home to the Dulwich Picture Gallery',
#   'line_2': 'Historic village with green spaces',
#   'line_3': 'Sought-after area for families'},
#  {'place_name': 'Kidbrooke',
#   'full_response': "['Home to the historic Kidbrooke Village','Former site of the AEG factory','Green spaces and the River Quaggy']",
#   'line_1': 'Home to the historic Kidbrooke Village',
#   'line_2': 'Former site of the AEG factory',
#   'line_3': 'Green spaces and the River Quaggy'},
#  {'place_name': 'East Ham',
#   'full_response': "['Old railway town charm','East Ham Memorial Park vibes','Culture-rich, diverse high streets']",
#   'line_1': 'Old railway town charm',
#   'line_2': 'East Ham Memorial Park vibes',
#   'line_3': 'Culture-rich, diverse high streets'},
#  {'place_name': 'Stratford',
#   'full_response': "['Home of the 2012 Olympics', 'Site of Shakespeare’s early plays', 'Gateway to the Olympic Park']",
#   'line_1': 'Home of the 2012 Olympics',
#   'line_2': 'Site of Shakespeare’s early plays',
#   'line_3': 'Gateway to the Olympic Park'},
#  {'place_name': 'Muswell Hill',
#   'full_response': "['Home of the iconic Alexandra Palace', 'Quaint shops with a creative flair', 'Vistas over the city skyline']",
#   'line_1': 'Home of the iconic Alexandra Palace',
#   'line_2': 'Quaint shops with a creative flair',
#   'line_3': 'Vistas over the city skyline'},
#  {'place_name': 'Finchley',
#   'full_response': "['Home of the iconic Finchley Lido', 'Once a bustling market town', 'Famous for its 18th-century pubs']",
#   'line_1': 'Home of the iconic Finchley Lido',
#   'line_2': 'Once a bustling market town',
#   'line_3': 'Famous for its 18th-century pubs'},
#  {'place_name': 'Queensbury',
#   'full_response': "['Home of the historic Tesco site','Once a hub for textiles','Close to the iconic Palace Theatre']",
#   'line_1': 'Home of the historic Tesco site',
#   'line_2': 'Once a hub for textiles',
#   'line_3': 'Close to the iconic Palace Theatre'},
#  {'place_name': 'Northolt',
#   'full_response': "['Home to historic Northolt Manor','Famous for the Northolt Carnival','Gateway to London’s green spaces']",
#   'line_1': 'Home to historic Northolt Manor',
#   'line_2': 'Famous for the Northolt Carnival',
#   'line_3': 'Gateway to London’s green spaces'},
#  {'place_name': 'Osterley',
#   'full_response': "['Home to Osterley Park estate', 'Historic links to the silk trade', 'Charming suburban village vibe']",
#   'line_1': 'Home to Osterley Park estate',
#   'line_2': 'Historic links to the silk trade',
#   'line_3': 'Charming suburban village vibe'},
#  {'place_name': 'Twickenham',
#   'full_response': "['Home of England rugby','Scenic walks by the Thames','Historic buildings and riverside pubs']",
#   'line_1': 'Home of England rugby',
#   'line_2': 'Scenic walks by the Thames',
#   'line_3': 'Historic buildings and riverside pubs'},
#  {'place_name': 'Ham',
#   'full_response': "['Historic riverside charm','Birthplace of the Beatles','Quaint streets and lively markets']",
#   'line_1': 'Historic riverside charm',
#   'line_2': 'Birthplace of the Beatles',
#   'line_3': 'Quaint streets and lively markets'},
#  {'place_name': 'Wimbledon',
#   'full_response': "['Home of the Wimbledon Championships','Historic village charm','Picturesque Commons and green spaces']",
#   'line_1': 'Home of the Wimbledon Championships',
#   'line_2': 'Historic village charm',
#   'line_3': 'Picturesque Commons and green spaces'},
#  {'place_name': 'Mottingham',
#   'full_response': "['Victorian homes line the streets','Green spaces and local parks','Old village charm in the suburbs']",
#   'line_1': 'Victorian homes line the streets',
#   'line_2': 'Green spaces and local parks',
#   'line_3': 'Old village charm in the suburbs'},
#  {'place_name': 'New Eltham',
#   'full_response': "['The historic village green charm','Home of the old Eltham Palace','Quiet suburban streets and parks']",
#   'line_1': 'The historic village green charm',
#   'line_2': 'Home of the old Eltham Palace',
#   'line_3': 'Quiet suburban streets and parks'},
#  {'place_name': 'Plumstead',
#   'full_response': "['Home to the Plumstead Common','Historic area with Victorian homes','Bustling market days on Saturdays']",
#   'line_1': 'Home to the Plumstead Common',
#   'line_2': 'Historic area with Victorian homes',
#   'line_3': 'Bustling market days on Saturdays'}]

# %%
places_wgs84_with_response = places_wgs84.merge(headlines_batch_df, left_on="GAZETTEER_ENTRY.NAME1", right_on="place_name", how='left')

# %%
places_wgs84_with_response.head(10)
# Out:
#      GAZETTEER_ENTRY.NAME1  GAZETTEER_ENTRY.MOST_DETAIL_VIEW_RES  \
# 0                  Beckton                                 20000
# 1                 Plaistow                                 18000
# 2           Leyton Marshes                                 18000
# 3          Stoke Newington                                 17000
# 4            Finsbury Park                                 17000
# 5                 Highgate                                 17000
# 6            East Finchley                                 25000
# 7  Hampstead Garden Suburb                                 16000
# 8            Golders Green                                 17000
# 9                   Hendon                                 29000
#
#    GAZETTEER_ENTRY.LEAST_DETAIL_VIEW_RES  \
# 0                                  25000
# 1                                  25000
# 2                                  25000
# 3                                  60000
# 4                                  25000
# 5                                  25000
# 6                                  26000
# 7                                  25000
# 8                                  25000
# 9                                  60000
#
#                        GAZETTEER_ENTRY.SAME_AS_DBPEDIA  \
# 0                  http://dbpedia.org/resource/Beckton
# 1         http://dbpedia.org/resource/Plaistow,_Newham
# 2                                                 None
# 3          http://dbpedia.org/resource/Stoke_Newington
# 4    http://dbpedia.org/resource/Finsbury_Park,_London
# 5                 http://dbpedia.org/resource/Highgate
# 6            http://dbpedia.org/resource/East_Finchley
# 7  http://dbpedia.org/resource/Hampstead_Garden_Suburb
# 8            http://dbpedia.org/resource/Golders_Green
# 9                   http://dbpedia.org/resource/Hendon
#
#                     geometry               place_name  \
# 0   POINT (0.05882 51.51583)                  Beckton
# 1   POINT (0.02419 51.52561)                 Plaistow
# 2  POINT (-0.04541 51.56873)           Leyton Marshes
# 3  POINT (-0.08352 51.56118)          Stoke Newington
# 4  POINT (-0.10889 51.56452)            Finsbury Park
# 5   POINT (-0.15285 51.5778)                 Highgate
# 6    POINT (-0.16633 51.585)            East Finchley
# 7  POINT (-0.18115 51.58118)  Hampstead Garden Suburb
# 8  POINT (-0.19712 51.58098)            Golders Green
# 9  POINT (-0.22859 51.58262)                   Hendon
#
#                                                                                                                                            full_response  \
# 0                                  1. Industrial Heart of East London   2. Maritime Gateway to the Thames   3. Victorian Innovation and Resilience Hub
# 1                               1. Historic Heartbeat of East London   2. Diverse Village of Resilient Roots   3. Industrial Legacy along the Greenway
# 2                             1. Resilient Green Heart of East London   2. Historic Refuge for Wild Creatures   3. Whispering Traces of Local Heritage
# 3  1. Green Sanctuary of London's Artists and Activists   2. Historic Hub of Dissent and Diversity   3. Vibrant Crossroads of Cultures and Communities
# 4              1. Victorian Oasis of Cultural Confluence   2. Historic Hub of Diverse Community Voices   3. Green Gateway to Urban Artistic Expression
# 5                              1. Whispering Streets of Victorian Elegance   2. Enigmatic Haven of Literary Rebels   3. Green Canopy of Historic Elysium
# 6                   1. Leafy Haven of Historic Village Charm   2. Cultural Crossroads of Diverse Communities   3. Gateway to Nature’s Edgware Greenery
# 7                   - Eden of Artistic Inspiration and Community   - Legacy of Garden City Visionaries    - Refuge of Edwardian Architectural Splendor
# 8                          1. Jewish Cultural Haven of North London   2. Historic Gateway to London's Suburbs   3. Bustling Hub of Spiritual Diversity
# 9                                - Unforgotten Realm of Historic Households   - Lively Enclave of Diverse Cultures   - Green Haven of London's Pasturoot
#
#                                               line_1  \
# 0                    Industrial Heart of East London
# 1                  Historic Heartbeat of East London
# 2               Resilient Green Heart of East London
# 3  Green Sanctuary of London's Artists and Activists
# 4             Victorian Oasis of Cultural Confluence
# 5           Whispering Streets of Victorian Elegance
# 6              Leafy Haven of Historic Village Charm
# 7                                               None
# 8              Jewish Cultural Haven of North London
# 9                                               None
#
#                                        line_2  \
# 0              Maritime Gateway to the Thames
# 1          Diverse Village of Resilient Roots
# 2          Historic Refuge for Wild Creatures
# 3       Historic Hub of Dissent and Diversity
# 4    Historic Hub of Diverse Community Voices
# 5          Enigmatic Haven of Literary Rebels
# 6  Cultural Crossroads of Diverse Communities
# 7                                        None
# 8        Historic Gateway to London's Suburbs
# 9                                        None
#
#                                            line_3 category_headline_1  \
# 0         Victorian Innovation and Resilience Hub                None
# 1            Industrial Legacy along the Greenway                None
# 2             Whispering Traces of Local Heritage                None
# 3  Vibrant Crossroads of Cultures and Communities                None
# 4      Green Gateway to Urban Artistic Expression                None
# 5                Green Canopy of Historic Elysium                None
# 6            Gateway to Nature’s Edgware Greenery                None
# 7                                            None                None
# 8             Bustling Hub of Spiritual Diversity                None
# 9                                            None                None
#
#   category_reason_1 category_headline_2 category_reason_2 category_headline_3  \
# 0              None                None              None                None
# 1              None                None              None                None
# 2              None                None              None                None
# 3              None                None              None                None
# 4              None                None              None                None
# 5              None                None              None                None
# 6              None                None              None                None
# 7              None                None              None                None
# 8              None                None              None                None
# 9              None                None              None                None
#
#   category_reason_3
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8              None
# 9              None

# %%
places_wgs84_with_response.to_file("data/places_wgs84_with_response.geojson", driver="GeoJSON")

# %%
# # Load environment variables from the .env file
# load_dotenv()
# # Access the API key
# chatgpt_api_key = os.getenv('CHATGPT_API_KEY_1')
# client = openai.OpenAI(api_key=chatgpt_api_key)

# %%
# for index, row in places_wgs84.iterrows():
#     place_name = row["GAZETTEER_ENTRY.NAME1"]
    
#     # Defining messages for ChatGPT
#     message_headlines = f"Give 3 distinct epithets that capture the historic narrative of {place_name}, each one unique and specific."

#     # Ensure ai_headlines is empty before making an API call
#     if row["ai_headlines"] is None or pd.isna(row["ai_headlines"]):  
#         completion = client.chat.completions.create(
#             model="gpt-4o-mini",
#             store=False,
#             messages=[
#                 {"role": "user", "content": message_headlines}
#             ]
#         )
#         # Correctly updating the DataFrame
#         places_wgs84.loc[index, "ai_headlines"] = completion.choices[0].message.content

# %%
# !pip install --upgrade openai

# %%
# client = OpenAI(api_key=chatgpt_api_key)

# completion = client.chat.completions.create(
#   model="gpt-4o-mini",
#   store=False,
#   messages=[
#     {"role": "user", "content": "write a haiku about ai"}
#   ]
# )

# print(completion.choices[0].message);

# %%
# wiki_gdf_dedupped['wiki_headline'] = None
# wiki_gdf_dedupped['wiki_categories'] = None

# %%
# places_gdf['place_headline'] = "lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua"
# places_gdf['place_categories'] = "royal, riverside, history"

# %%
# #Reprojecting gdf for mapbox
# places_gdf_wgs84 = places_gdf.to_crs(4258)
# print(places_gdf_wgs84.crs)
# print(places_gdf_wgs84.iloc[2]["geometry"]) #ensuring the coordinates have transformed
# places_gdf_wgs84.to_file("data/places_wgs84.geojson", driver="GeoJSON")
# Out:
# EPSG:4258
# POINT (0.0772798084689046 51.50684263876633)

# %%
# places_gdf_wgs84
